# %%
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt
import seaborn as sns
import geobr
import geopandas as gpd
import matplotlib as mpl

# %%
file_path = './1 - Organized data gauge/BRAZIL/DATASETS/BRAZIL_DAILY_1961_2024_CLEANED.h5'

# %%
with h5py.File(file_path, 'r') as hdf:
    keys = list(hdf.keys())
    print(keys)
# Out:
# ['table_data', 'table_data_filtered', 'table_info', 'table_p_availability', 'table_preclassif', 'table_q1_gaps', 'table_q2_week', 'table_q3_outliers', 'table_qc_info']

# %%
df_info = pd.read_hdf(file_path, key='table_info')
df_info
# Out:
#                      name_station gauge_code                 city  \
# 18981             SELVIRIA | S717       S717             SELVIRIA
# 18980  SANTA RITA DO PARDO | S716       S716  SANTA RITA DO PARDO
# 18979   RIBAS DO RIO PARDO | S715       S715   RIBAS DO RIO PARDO
# 18978          PEDRO GOMES | S714       S714          PEDRO GOMES
# 18977       NOVA ANDRADINA | S713       S713       NOVA ANDRADINA
# ...                           ...        ...                  ...
# 4                          MARUDA   00047005            MARAPANIM
# 3                       PRIMAVERA   00047004            PRIMAVERA
# 2                          CURUÇA   00047003               CURUÇA
# 1                     SALINÓPOLIS   00047002          SALINÓPOLIS
# 0                     SALINÓPOLIS   00047000          SALINÓPOLIS
#
#                     state responsible    source state_abbreviation        lat  \
# 18981  MATO GROSSO DO SUL       INMET     INMET                 MS -20.351389
# 18980  MATO GROSSO DO SUL       INMET     INMET                 MS -21.305889
# 18979  MATO GROSSO DO SUL       INMET     INMET                 MS -20.466694
# 18978  MATO GROSSO DO SUL       INMET     INMET                 MS -18.072778
# 18977  MATO GROSSO DO SUL       INMET     INMET                 MS -22.078611
# ...                   ...         ...       ...                ...        ...
# 4                    PARÁ         ANA  HIDROWEB                 PA  -0.633600
# 3                    PARÁ         ANA  HIDROWEB                 PA  -0.929400
# 2                    PARÁ         ANA  HIDROWEB                 PA  -0.737500
# 1                    PARÁ         ANA  HIDROWEB                 PA  -0.623100
# 0                    PARÁ       INMET  HIDROWEB                 PA  -0.650000
#
#             long
# 18981 -51.430278
# 18980 -52.820375
# 18979 -53.763028
# 18978 -54.548889
# 18977 -53.465833
# ...          ...
# 4     -47.658300
# 3     -47.099400
# 2     -47.853600
# 1     -47.353600
# 0     -47.550000
#
# [18370 rows x 9 columns]

# %%
station_list = df_info['gauge_code'].unique()
print(len(station_list), station_list) # len()
# Out:
# 18370 ['S717' 'S716' 'S715' ... '00047003' '00047002' '00047000']

# %%
df_data = pd.DataFrame()  # Initialize an empty DataFrame

count = 0
# Read the HDF file in chunks
for chunk in pd.read_hdf(file_path, key='table_data_filtered', encoding='utf-8', chunksize=12400000, iterator=True):
    chunk = chunk[chunk['gauge_code'].isin(station_list)]
    if df_data.empty:
        df_data = chunk.copy(deep=True)  # If this is the first chunk, assign it directly to df_data
    else:
        df_data = pd.concat([df_data, chunk], ignore_index=True)
    count = count + 1
    print(f"Processed chunk {count}")
df_data['year'] = pd.to_datetime(df_data['datetime']).dt.year
df_data
# Out:
# Processed chunk 1
# Processed chunk 2
# Processed chunk 3
# Processed chunk 4
# Processed chunk 5
# Processed chunk 6
# Processed chunk 7
# Processed chunk 8
# Processed chunk 9
# Processed chunk 10
#           gauge_code   datetime  rain_mm  year
# 0           00047000 1961-01-01      0.0  1961
# 1           00047000 1961-01-02      0.0  1961
# 2           00047000 1961-01-03      0.0  1961
# 3           00047000 1961-01-04      0.0  1961
# 4           00047000 1961-01-05      0.0  1961
# ...              ...        ...      ...   ...
# 123593340       S717 2021-12-27      0.0  2021
# 123593341       S717 2021-12-28      0.0  2021
# 123593342       S717 2021-12-29      0.0  2021
# 123593343       S717 2021-12-30      0.0  2021
# 123593344       S717 2021-12-31      0.0  2021
#
# [123593345 rows x 4 columns]

# %%
del chunk  # Delete the chunk variable to free up memory

# %%
df_qc_info = pd.read_hdf(file_path, key='table_qc_info')

lower_limit = 60

df_qc_info['final_classif'] = np.where(
    # (df_qc_info['q1_gaps'] < lower_limit) |
    # (df_qc_info['q2_week'] < lower_limit) |
    # (df_qc_info['q3_outliers'] < lower_limit) |
    (df_qc_info['quality_index'] < 80) |
    (df_qc_info['p_availability'] < 90) |
    (df_qc_info['preclassif'] == 'LQ') |
    (df_qc_info['final_classif'] == 'LQ'),
    'LQ',
    df_qc_info['final_classif']
)
df_qc_info
# Out:
#        gauge_code  year  annual_rainfall_mm  active_days  \
# 0        00047000  1961              2186.0        365.0
# 1        00047000  1962               273.8        365.0
# 2        00047000  1963               686.2        365.0
# 3        00047000  1964               597.5        366.0
# 4        00047002  1977               133.4         23.0
# ...           ...   ...                 ...          ...
# 345863       S713  2021                76.2        365.0
# 345864       S714  2021               828.0        365.0
# 345865       S715  2021              1041.8        365.0
# 345866       S716  2021               928.8        365.0
# 345867       S717  2021                 0.0        365.0
#
#         consecutive_dry_days preclassif  p_availability  q1_gaps    q2_week  \
# 0                      265.0         LQ       100.00000    100.0  71.803161
# 1                       93.0                  100.00000    100.0  69.402386
# 2                       71.0                  100.00000    100.0  66.650234
# 3                       93.0                  100.00000    100.0  87.798731
# 4                        5.0         LQ         6.30137      0.0   6.458565
# ...                      ...        ...             ...      ...        ...
# 345863                 137.0         LQ       100.00000    100.0  62.583426
# 345864                  58.0                  100.00000    100.0  63.664531
# 345865                  38.0                  100.00000    100.0  76.074189
# 345866                  32.0                  100.00000    100.0  74.501053
# 345867                 365.0         LQ       100.00000    100.0   0.000000
#
#         q3_outliers  ...                name_station                 city  \
# 0         98.082192  ...                 SALINÓPOLIS          SALINÓPOLIS
# 1         99.452055  ...                 SALINÓPOLIS          SALINÓPOLIS
# 2         99.726027  ...                 SALINÓPOLIS          SALINÓPOLIS
# 3         99.726776  ...                 SALINÓPOLIS          SALINÓPOLIS
# 4         91.304348  ...                 SALINÓPOLIS          SALINÓPOLIS
# ...             ...  ...                         ...                  ...
# 345863    99.726027  ...       NOVA ANDRADINA | S713       NOVA ANDRADINA
# 345864    99.178082  ...          PEDRO GOMES | S714          PEDRO GOMES
# 345865    98.630137  ...   RIBAS DO RIO PARDO | S715   RIBAS DO RIO PARDO
# 345866    98.904110  ...  SANTA RITA DO PARDO | S716  SANTA RITA DO PARDO
# 345867   100.000000  ...             SELVIRIA | S717             SELVIRIA
#
#                      state responsible    source state_abbreviation  \
# 0                     PARÁ       INMET  HIDROWEB                 PA
# 1                     PARÁ       INMET  HIDROWEB                 PA
# 2                     PARÁ       INMET  HIDROWEB                 PA
# 3                     PARÁ       INMET  HIDROWEB                 PA
# 4                     PARÁ         ANA  HIDROWEB                 PA
# ...                    ...         ...       ...                ...
# 345863  MATO GROSSO DO SUL       INMET     INMET                 MS
# 345864  MATO GROSSO DO SUL       INMET     INMET                 MS
# 345865  MATO GROSSO DO SUL       INMET     INMET                 MS
# 345866  MATO GROSSO DO SUL       INMET     INMET                 MS
# 345867  MATO GROSSO DO SUL       INMET     INMET                 MS
#
#               lat       long        region  final_classif
# 0       -0.650000 -47.550000         North             LQ
# 1       -0.650000 -47.550000         North             HQ
# 2       -0.650000 -47.550000         North             HQ
# 3       -0.650000 -47.550000         North             HQ
# 4       -0.623100 -47.353600         North             LQ
# ...           ...        ...           ...            ...
# 345863 -22.078611 -53.465833  Central-West             LQ
# 345864 -18.072778 -54.548889  Central-West             HQ
# 345865 -20.466694 -53.763028  Central-West             HQ
# 345866 -21.305889 -52.820375  Central-West             HQ
# 345867 -20.351389 -51.430278  Central-West             LQ
#
# [345868 rows x 22 columns]

# %%
df_data_loss = df_qc_info[['gauge_code', 'year', 'preclassif', 'final_classif']]
df_data_loss = pd.merge(df_data, df_data_loss[['gauge_code', 'year', 'preclassif', 'final_classif']], on=['gauge_code', 'year'], how='left')
df_data_loss
# Out:
#           gauge_code   datetime  rain_mm  year preclassif final_classif
# 0           00047000 1961-01-01      0.0  1961         LQ            LQ
# 1           00047000 1961-01-02      0.0  1961         LQ            LQ
# 2           00047000 1961-01-03      0.0  1961         LQ            LQ
# 3           00047000 1961-01-04      0.0  1961         LQ            LQ
# 4           00047000 1961-01-05      0.0  1961         LQ            LQ
# ...              ...        ...      ...   ...        ...           ...
# 123593340       S717 2021-12-27      0.0  2021         LQ            LQ
# 123593341       S717 2021-12-28      0.0  2021         LQ            LQ
# 123593342       S717 2021-12-29      0.0  2021         LQ            LQ
# 123593343       S717 2021-12-30      0.0  2021         LQ            LQ
# 123593344       S717 2021-12-31      0.0  2021         LQ            LQ
#
# [123593345 rows x 6 columns]

# %%
preclassif_count = df_data_loss[df_data_loss['preclassif'] != 'LQ'].shape[0]
final_classif_count = df_data_loss[df_data_loss['final_classif'] != 'LQ'].shape[0]

print("Rows where 'preclassif' != 'LQ':", preclassif_count)
print("Rows where 'final_classif' != 'LQ':", final_classif_count)

# Rows where 'preclassif' != 'LQ': 107835098
# Rows where 'final_classif' != 'LQ': 107431189
# Out:
# Rows where 'preclassif' != 'LQ': 112619782
# Rows where 'final_classif' != 'LQ': 101479598

# %%
del preclassif_count  # Delete the preclassif_count variable to free up memory
del final_classif_count  # Delete the final_classif_count variable to free up memory

# %%
df_data_loss = df_data_loss[df_data_loss['preclassif'] != 'LQ']
print(df_data_loss.shape[0], len(df_data_loss['gauge_code'].unique()))  # len()
# Out:
# 112619782 17833

# %%
df_data_loss.pop('preclassif')
# Out:
# 365
# 366
# 367
# 368
# 369
#             ..
# 123592975
# 123592976
# 123592977
# 123592978
# 123592979
# Name: preclassif, Length: 112619782, dtype: object

# %%
df_data_loss = df_data_loss[df_data_loss['final_classif'] != 'LQ']
print(len(df_data_loss), len(df_data_loss['gauge_code'].unique()))

# 110574472 17283
# Out:
# 101479598 17150

# %%
del df_data_loss

# %%
df_data
# Out:
#           gauge_code   datetime  rain_mm  year
# 0           00047000 1961-01-01      0.0  1961
# 1           00047000 1961-01-02      0.0  1961
# 2           00047000 1961-01-03      0.0  1961
# 3           00047000 1961-01-04      0.0  1961
# 4           00047000 1961-01-05      0.0  1961
# ...              ...        ...      ...   ...
# 123593340       S717 2021-12-27      0.0  2021
# 123593341       S717 2021-12-28      0.0  2021
# 123593342       S717 2021-12-29      0.0  2021
# 123593343       S717 2021-12-30      0.0  2021
# 123593344       S717 2021-12-31      0.0  2021
#
# [123593345 rows x 4 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_data_qc = pd.merge(df_data, df_qc_info[['gauge_code', 'year', 'final_classif']], on=['gauge_code', 'year'], how='left')
df_data_qc = df_data_qc[df_data_qc['final_classif'] == 'HQ']
df_data_qc = df_data_qc[['gauge_code', 'datetime', 'rain_mm']]
df_data_qc
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_info_qc = df_info[df_info['gauge_code'].isin(df_data_qc['gauge_code'].unique())]
df_info_qc.reset_index(drop=True, inplace=True)
df_info_qc
# Out:
#                       name_station gauge_code                  city  \
# 0       SANTA RITA DO PARDO | S716       S716   SANTA RITA DO PARDO
# 1        RIBAS DO RIO PARDO | S715       S715    RIBAS DO RIO PARDO
# 2      NOVA ALVORADA DO SUL | S712       S712  NOVA ALVORADA DO SUL
# 3             LAGUNA CARAPA | S711       S711         LAGUNA CARAPA
# 4                   ITAPORA | S710       S710               ITAPORA
# ...                            ...        ...                   ...
# 16836                       MARUDA   00047005             MARAPANIM
# 16837                    PRIMAVERA   00047004             PRIMAVERA
# 16838                       CURUÇA   00047003                CURUÇA
# 16839                  SALINÓPOLIS   00047002           SALINÓPOLIS
# 16840                  SALINÓPOLIS   00047000           SALINÓPOLIS
#
#                     state responsible    source state_abbreviation        lat  \
# 0      MATO GROSSO DO SUL       INMET     INMET                 MS -21.305889
# 1      MATO GROSSO DO SUL       INMET     INMET                 MS -20.466694
# 2      MATO GROSSO DO SUL       INMET     INMET                 MS -21.450972
# 3      MATO GROSSO DO SUL       INMET     INMET                 MS -22.575389
# 4      MATO GROSSO DO SUL       INMET     INMET                 MS -22.092833
# ...                   ...         ...       ...                ...        ...
# 16836                PARÁ         ANA  HIDROWEB                 PA  -0.633600
# 16837                PARÁ         ANA  HIDROWEB                 PA  -0.929400
# 16838                PARÁ         ANA  HIDROWEB                 PA  -0.737500
# 16839                PARÁ         ANA  HIDROWEB                 PA  -0.623100
# 16840                PARÁ       INMET  HIDROWEB                 PA  -0.650000
#
#             long
# 0     -52.820375
# 1     -53.763028
# 2     -54.341972
# 3     -55.160333
# 4     -54.798833
# ...          ...
# 16836 -47.658300
# 16837 -47.099400
# 16838 -47.853600
# 16839 -47.353600
# 16840 -47.550000
#
# [16841 rows x 9 columns]

# %%
del df_info
del df_data, df_qc_info

# %%
df_info_qc.to_hdf('./1 - Organized data gauge/BRAZIL/DATASETS/BRAZIL_DAILY_1961_2024_QC.h5', key='table_info', mode='w', format='table', encoding='utf-8', index=False, complevel=9)

# %%
chunk_size = 12000000  # Define the chunk size
with pd.HDFStore('./1 - Organized data gauge/BRAZIL/DATASETS/BRAZIL_DAILY_1961_2024_QC.h5', mode='r+', complevel=9) as store:
    for i in range(0, len(df_data_qc), chunk_size):
        chunk = df_data_qc.iloc[i:i + chunk_size]
        chunk.to_hdf(store
                     , key='table_data'
                     , format='table'
                     , append=True
                     , index=False
                     , encoding='utf-8'
                     , mode='a'
                     , complevel=9
                     , min_itemsize={'gauge_code': 15})
        print(f"Appended chunk {i // chunk_size + 1}")
# Out:
# Appended chunk 1
# Appended chunk 2
# Appended chunk 3
# Appended chunk 4
# Appended chunk 5
# Appended chunk 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 5
#       3 for i in range(0, len(df_data_qc), chunk_size):
#       4     chunk = df_data_qc.iloc[i:i + chunk_size]
# ----> 5     chunk.to_hdf(store
#       6                  , key='table_data'
#       7                  , format='table'
#       8                  , append=True
#       9                  , index=False
#      10                  , encoding='utf-8'
#      11                  , mode='a'
#      12                  , complevel=9
#      13                  , min_itemsize={'gauge_code': 15})
#      14     print(f"Appended chunk {i // chunk_size + 1}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:2855, in NDFrame.to_hdf(self, path_or_buf, key, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#    2851 from pandas.io import pytables
#    2853 # Argument 3 to "to_hdf" has incompatible type "NDFrame"; expected
#    2854 # "Union[DataFrame, Series]" [arg-type]
# -> 2855 pytables.to_hdf(
#    2856     path_or_buf,
#    2857     key,
#    2858     self,  # type: ignore[arg-type]
#    2859     mode=mode,
#    2860     complevel=complevel,
#    2861     complib=complib,
#    2862     append=append,
#    2863     format=format,
#    2864     index=index,
#    2865     min_itemsize=min_itemsize,
#    2866     nan_rep=nan_rep,
#    2867     dropna=dropna,
#    2868     data_columns=data_columns,
#    2869     errors=errors,
#    2870     encoding=encoding,
#    2871 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\pytables.py:311, in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#     307 if isinstance(path_or_buf, str):
#     308     with HDFStore(
#     309         path_or_buf, mode=mode, complevel=complevel, complib=complib
#     310     ) as store:
# --> 311         f(store)
#     312 else:
#     313     f(path_or_buf)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\pytables.py:279, in to_hdf.<locals>.<lambda>(store)
#     277 """store this object, close it if we opened it"""
#     278 if append:
# --> 279     f = lambda store: store.append(
#     280         key,
#     281         value,
#     282         format=format,
#     283         index=index,
#     284         min_itemsize=min_itemsize,
#     285         nan_rep=nan_rep,
#     286         dropna=dropna,
#     287         data_columns=data_columns,
#     288         errors=errors,
#     289         encoding=encoding,
#     290     )
#     291 else:
#     292     # NB: dropna is not passed to `put`
#     293     f = lambda store: store.put(
#     294         key,
#     295         value,
#    (...)
#     303         dropna=dropna,
#     304     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\pytables.py:1317, in HDFStore.append(self, key, value, format, axes, index, append, complib, complevel, columns, min_itemsize, nan_rep, chunksize, expectedrows, dropna, data_columns, encoding, errors)
#    1315     format = get_option("io.hdf.default_format") or "table"
#    1316 format = self._validate_format(format)
# -> 1317 self._write_to_group(
#    1318     key,
#    1319     value,
#    1320     format=format,
#    1321     axes=axes,
#    1322     index=index,
#    1323     append=append,
#    1324     complib=complib,
#    1325     complevel=complevel,
#    1326     min_itemsize=min_itemsize,
#    1327     nan_rep=nan_rep,
#    1328     chunksize=chunksize,
#    1329     expectedrows=expectedrows,
#    1330     dropna=dropna,
#    1331     data_columns=data_columns,
#    1332     encoding=encoding,
#    1333     errors=errors,
#    1334 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\pytables.py:1858, in HDFStore._write_to_group(self, key, value, format, axes, index, append, complib, complevel, fletcher32, min_itemsize, chunksize, expectedrows, dropna, nan_rep, data_columns, encoding, errors, track_times)
#    1855     raise ValueError("Compression not supported on Fixed format stores")
#    1857 # write the object
# -> 1858 s.write(
#    1859     obj=value,
#    1860     axes=axes,
#    1861     append=append,
#    1862     complib=complib,
#    1863     complevel=complevel,
#    1864     fletcher32=fletcher32,
#    1865     min_itemsize=min_itemsize,
#    1866     chunksize=chunksize,
#    1867     expectedrows=expectedrows,
#    1868     dropna=dropna,
#    1869     nan_rep=nan_rep,
#    1870     data_columns=data_columns,
#    1871     track_times=track_times,
#    1872 )
#    1874 if isinstance(s, Table) and index:
#    1875     s.create_index(columns=index)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\pytables.py:4434, in AppendableTable.write(self, obj, axes, append, complib, complevel, fletcher32, min_itemsize, chunksize, expectedrows, dropna, nan_rep, data_columns, track_times)
#    4431     a.validate_and_set(table, append)
#    4433 # add the rows
# -> 4434 table.write_data(chunksize, dropna=dropna)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\pytables.py:4488, in AppendableTable.write_data(self, chunksize, dropna)
#    4485 if start_i >= end_i:
#    4486     break
# -> 4488 self.write_data_chunk(
#    4489     rows,
#    4490     indexes=[a[start_i:end_i] for a in indexes],
#    4491     mask=mask[start_i:end_i] if mask is not None else None,
#    4492     values=[v[start_i:end_i] for v in bvalues],
#    4493 )
#
# KeyboardInterrupt:

# %%
del chunk, df_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 del chunk, df_data
#
# NameError: name 'df_data' is not defined

# %%
df_data_qc = pd.read_hdf('./1 - Organized data gauge/BRAZIL/DATASETS/BRAZIL_DAILY_1961_2024_QC.h5', key='table_data')
df_data_qc
# Out:
#           gauge_code   datetime  rain_mm
# 365         00047000 1962-01-01      0.0
# 366         00047000 1962-01-02      0.0
# 367         00047000 1962-01-03      0.0
# 368         00047000 1962-01-04      0.0
# 369         00047000 1962-01-05      0.0
# ...              ...        ...      ...
# 123592975       S716 2021-12-27      0.0
# 123592976       S716 2021-12-28      0.0
# 123592977       S716 2021-12-29      0.0
# 123592978       S716 2021-12-30      4.4
# 123592979       S716 2021-12-31      3.2
#
# [110574472 rows x 3 columns]
