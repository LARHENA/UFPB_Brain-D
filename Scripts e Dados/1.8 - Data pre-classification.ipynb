# %%
import pandas as pd
import numpy as np
from scipy.spatial import KDTree
import os

# %% [markdown]
# # Data processing

# %%
neighboring_data_path = './1 - Organized data gauge/BRAZIL'
cleaned_path = './1 - Organized data gauge/BRAZIL/DATASETS/BRAZIL_DAILY_1961_2024_CLEANED.h5'

# %%
df_data = pd.read_hdf(cleaned_path, key = 'table_data', encoding = 'utf-8')
df_data
# Out:
#         gauge_code   datetime  rain_mm
# 0         00047000 1961-01-01      0.0
# 1         00047000 1961-01-02      0.0
# 2         00047000 1961-01-03      0.0
# 3         00047000 1961-01-04      0.0
# 4         00047000 1961-01-05      0.0
# ...            ...        ...      ...
# 1076753       S717 2021-12-27      0.0
# 1076754       S717 2021-12-28      0.0
# 1076755       S717 2021-12-29      0.0
# 1076756       S717 2021-12-30      0.0
# 1076757       S717 2021-12-31      0.0
#
# [123612842 rows x 3 columns]

# %%
df_info = pd.read_hdf(cleaned_path, key = 'table_info', encoding = 'utf-8')
df_info
# Out:
#                      name_station gauge_code                 city  \
# 18981             SELVIRIA | S717       S717             SELVIRIA
# 18980  SANTA RITA DO PARDO | S716       S716  SANTA RITA DO PARDO
# 18979   RIBAS DO RIO PARDO | S715       S715   RIBAS DO RIO PARDO
# 18978          PEDRO GOMES | S714       S714          PEDRO GOMES
# 18977       NOVA ANDRADINA | S713       S713       NOVA ANDRADINA
# ...                           ...        ...                  ...
# 4                          MARUDA   00047005            MARAPANIM
# 3                       PRIMAVERA   00047004            PRIMAVERA
# 2                          CURUÇA   00047003               CURUÇA
# 1                     SALINÓPOLIS   00047002          SALINÓPOLIS
# 0                     SALINÓPOLIS   00047000          SALINÓPOLIS
#
#                     state responsible    source state_abbreviation        lat  \
# 18981  MATO GROSSO DO SUL       INMET     INMET                 MS -20.351389
# 18980  MATO GROSSO DO SUL       INMET     INMET                 MS -21.305889
# 18979  MATO GROSSO DO SUL       INMET     INMET                 MS -20.466694
# 18978  MATO GROSSO DO SUL       INMET     INMET                 MS -18.072778
# 18977  MATO GROSSO DO SUL       INMET     INMET                 MS -22.078611
# ...                   ...         ...       ...                ...        ...
# 4                    PARÁ         ANA  HIDROWEB                 PA  -0.633600
# 3                    PARÁ         ANA  HIDROWEB                 PA  -0.929400
# 2                    PARÁ         ANA  HIDROWEB                 PA  -0.737500
# 1                    PARÁ         ANA  HIDROWEB                 PA  -0.623100
# 0                    PARÁ       INMET  HIDROWEB                 PA  -0.650000
#
#             long
# 18981 -51.430278
# 18980 -52.820375
# 18979 -53.763028
# 18978 -54.548889
# 18977 -53.465833
# ...          ...
# 4     -47.658300
# 3     -47.099400
# 2     -47.853600
# 1     -47.353600
# 0     -47.550000
#
# [18370 rows x 9 columns]

# %%
df_complete_info = pd.merge(df_data, df_info, on='gauge_code', how = 'inner').sort_values('lat', ascending = True)
# .dropna(how='any')
df_complete_info

# left: 123612842 rows
# inner: 123596321 rows
# Out:
#           gauge_code   datetime  rain_mm  \
# 123521436       A899 2022-01-13      0.0
# 123521704       A899 2022-10-08      0.0
# 123521705       A899 2022-10-09      2.4
# 123521706       A899 2022-10-10      0.0
# 123521707       A899 2022-10-11      0.0
# ...              ...        ...      ...
# 114849060   08460003 2017-01-07      0.0
# 114849061   08460003 2017-01-08      0.0
# 114849062   08460003 2017-01-09      0.0
# 114849049   08460003 2016-12-27      0.0
# 114843719   08460003 2002-05-25      3.1
#
#                                              name_station  \
# 123521436  Santa Vitoria do Palmar - Barra do Chui | A899
# 123521704  Santa Vitoria do Palmar - Barra do Chui | A899
# 123521705  Santa Vitoria do Palmar - Barra do Chui | A899
# 123521706  Santa Vitoria do Palmar - Barra do Chui | A899
# 123521707  Santa Vitoria do Palmar - Barra do Chui | A899
# ...                                                   ...
# 114849060                                       ÁGUA FRIA
# 114849061                                       ÁGUA FRIA
# 114849062                                       ÁGUA FRIA
# 114849049                                       ÁGUA FRIA
# 114843719                                       ÁGUA FRIA
#
#                                               city              state  \
# 123521436  SANTA VITORIA DO PALMAR - BARRA DO CHUI  RIO GRANDE DO SUL
# 123521704  SANTA VITORIA DO PALMAR - BARRA DO CHUI  RIO GRANDE DO SUL
# 123521705  SANTA VITORIA DO PALMAR - BARRA DO CHUI  RIO GRANDE DO SUL
# 123521706  SANTA VITORIA DO PALMAR - BARRA DO CHUI  RIO GRANDE DO SUL
# 123521707  SANTA VITORIA DO PALMAR - BARRA DO CHUI  RIO GRANDE DO SUL
# ...                                            ...                ...
# 114849060                                 UIRAMUTA            RORAIMA
# 114849061                                 UIRAMUTA            RORAIMA
# 114849062                                 UIRAMUTA            RORAIMA
# 114849049                                 UIRAMUTA            RORAIMA
# 114843719                                 UIRAMUTA            RORAIMA
#
#           responsible    source state_abbreviation        lat       long
# 123521436       INMET     INMET                 RS -33.742222 -53.372222
# 123521704       INMET     INMET                 RS -33.742222 -53.372222
# 123521705       INMET     INMET                 RS -33.742222 -53.372222
# 123521706       INMET     INMET                 RS -33.742222 -53.372222
# 123521707       INMET     INMET                 RS -33.742222 -53.372222
# ...               ...       ...                ...        ...        ...
# 114849060         ANA  HIDROWEB                 RR   4.642800 -60.496400
# 114849061         ANA  HIDROWEB                 RR   4.642800 -60.496400
# 114849062         ANA  HIDROWEB                 RR   4.642800 -60.496400
# 114849049         ANA  HIDROWEB                 RR   4.642800 -60.496400
# 114843719         ANA  HIDROWEB                 RR   4.642800 -60.496400
#
# [123596321 rows x 11 columns]

# %%
len(df_complete_info['gauge_code'].unique())
# Out:
# 18370

# %%
len(df_info['gauge_code'].unique())
# Out:
# 18370

# %%
# Add a year column to the dataframe
df_complete_info['year'] = df_complete_info['datetime'].dt.year

# Group by gauge_code and year
grouped = df_complete_info.groupby(['gauge_code', 'year'])

# Calculate annual_rainfall_mm, active_days, and consecutive_dry_days
def calculate_metrics(group):
    annual_rainfall_mm = group['rain_mm'].sum()
    active_days = (group['rain_mm'] >= 0.0).sum()
    
    # Calculate consecutive dry days
    dry_days = (group['rain_mm'] == 0.0).astype(int)
    # Calculate the maximum number of consecutive dry days
    consecutive_dry_days = (dry_days.groupby((dry_days != dry_days.shift()).cumsum()).cumsum() * dry_days).max()
    
    return pd.Series({
        'annual_rainfall_mm': annual_rainfall_mm,
        'active_days': active_days,
        'consecutive_dry_days': consecutive_dry_days
    })

# %%
df_preclassif = grouped.apply(calculate_metrics).reset_index()
df_preclassif

# 345868 rows × 5 columns
# Out:
# C:\Users\linde\AppData\Local\Temp\ipykernel_23124\938018120.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_preclassif = grouped.apply(calculate_metrics).reset_index()
#        gauge_code  year  annual_rainfall_mm  active_days  consecutive_dry_days
# 0        00047000  1961              2186.0        365.0                 265.0
# 1        00047000  1962               273.8        365.0                  93.0
# 2        00047000  1963               686.2        365.0                  71.0
# 3        00047000  1964               597.5        366.0                  93.0
# 4        00047002  1977               133.4         23.0                   5.0
# ...           ...   ...                 ...          ...                   ...
# 345863       S713  2021                76.2        365.0                 137.0
# 345864       S714  2021               828.0        365.0                  58.0
# 345865       S715  2021              1041.8        365.0                  38.0
# 345866       S716  2021               928.8        365.0                  32.0
# 345867       S717  2021                 0.0        365.0                 365.0
#
# [345868 rows x 5 columns]

# %%
df_preclassif['preclassif'] = df_preclassif.apply(
    lambda row: 'LQ' if (row['annual_rainfall_mm'] < 200 or row['annual_rainfall_mm'] > 6000
                        #  or row['active_days'] < 305
                         or row['consecutive_dry_days'] > 200) else "", axis=1)
df_preclassif
# Out:
#        gauge_code  year  annual_rainfall_mm  active_days  \
# 0        00047000  1961              2186.0        365.0
# 1        00047000  1962               273.8        365.0
# 2        00047000  1963               686.2        365.0
# 3        00047000  1964               597.5        366.0
# 4        00047002  1977               133.4         23.0
# ...           ...   ...                 ...          ...
# 345863       S713  2021                76.2        365.0
# 345864       S714  2021               828.0        365.0
# 345865       S715  2021              1041.8        365.0
# 345866       S716  2021               928.8        365.0
# 345867       S717  2021                 0.0        365.0
#
#         consecutive_dry_days preclassif
# 0                      265.0         LQ
# 1                       93.0
# 2                       71.0
# 3                       93.0
# 4                        5.0         LQ
# ...                      ...        ...
# 345863                 137.0         LQ
# 345864                  58.0
# 345865                  38.0
# 345866                  32.0
# 345867                 365.0         LQ
#
# [345868 rows x 6 columns]

# %%
preclassif_counts = df_preclassif['preclassif'].value_counts()
print(preclassif_counts)
# Out:
# preclassif
#       313264
# LQ     32604
# Name: count, dtype: int64

# %%
preclassif_counts['LQ'] / preclassif_counts.sum()
# Out:
# 0.09426717707333433

# %%
df_preclassif.to_hdf(cleaned_path, key='table_preclassif', mode='r+', complevel=9, complib='zlib')
df_preclassif
# Out:
#        gauge_code  year  annual_rainfall_mm  active_days  \
# 0        00047000  1961              2186.0        365.0
# 1        00047000  1962               273.8        365.0
# 2        00047000  1963               686.2        365.0
# 3        00047000  1964               597.5        366.0
# 4        00047002  1977               133.4         23.0
# ...           ...   ...                 ...          ...
# 345863       S713  2021                76.2        365.0
# 345864       S714  2021               828.0        365.0
# 345865       S715  2021              1041.8        365.0
# 345866       S716  2021               928.8        365.0
# 345867       S717  2021                 0.0        365.0
#
#         consecutive_dry_days preclassif
# 0                      265.0         LQ
# 1                       93.0
# 2                       71.0
# 3                       93.0
# 4                        5.0         LQ
# ...                      ...        ...
# 345863                 137.0         LQ
# 345864                  58.0
# 345865                  38.0
# 345866                  32.0
# 345867                 365.0         LQ
#
# [345868 rows x 6 columns]

# %%
df_preclassif = pd.read_hdf(cleaned_path, key = 'table_preclassif', encoding = 'utf-8')
df_preclassif
# Out:
#        gauge_code  year  annual_rainfall_mm  active_days  \
# 0        00047000  1961              2186.0        365.0
# 1        00047000  1962               273.8        365.0
# 2        00047000  1963               686.2        365.0
# 3        00047000  1964               597.5        366.0
# 4        00047002  1977               133.4         23.0
# ...           ...   ...                 ...          ...
# 345863       S713  2021                76.2        365.0
# 345864       S714  2021               828.0        365.0
# 345865       S715  2021              1041.8        365.0
# 345866       S716  2021               928.8        365.0
# 345867       S717  2021                 0.0        365.0
#
#         consecutive_dry_days preclassif
# 0                      265.0         LQ
# 1                       93.0
# 2                       71.0
# 3                       93.0
# 4                        5.0         LQ
# ...                      ...        ...
# 345863                 137.0         LQ
# 345864                  58.0
# 345865                  38.0
# 345866                  32.0
# 345867                 365.0         LQ
#
# [345868 rows x 6 columns]

# %% [markdown]
# # Outlier treatment

# %%
df_outlier = pd.merge(df_complete_info[['gauge_code', 'rain_mm', 'datetime', 'year']], df_preclassif, on = ['gauge_code', 'year'], how = 'left')
df_outlier = df_outlier[df_outlier['preclassif'] != 'LQ']
df_outlier = df_outlier[['gauge_code',	'datetime',	'rain_mm']]
df_outlier
# Out:
#           gauge_code   datetime  rain_mm
# 0               A899 2022-01-13      0.0
# 1               A899 2022-10-08      0.0
# 2               A899 2022-10-09      2.4
# 3               A899 2022-10-10      0.0
# 4               A899 2022-10-11      0.0
# ...              ...        ...      ...
# 123596316   08460003 2017-01-07      0.0
# 123596317   08460003 2017-01-08      0.0
# 123596318   08460003 2017-01-09      0.0
# 123596319   08460003 2016-12-27      0.0
# 123596320   08460003 2002-05-25      3.1
#
# [112622758 rows x 3 columns]

# %%
del df_complete_info

# %%
def mark_outlier_rain(df, threshold_rain_mm=200):
    # Garantir que a coluna 'datetime' está no formato datetime
    df['datetime'] = pd.to_datetime(df['datetime'])

    # Ordenar por estação e data
    df_sorted = df.sort_values(['gauge_code', 'datetime']).copy()

    # Calcular chuva do dia anterior e do dia seguinte
    df_sorted['yesterday_rain_mm'] = df_sorted.groupby('gauge_code')['rain_mm'].shift(1)
    df_sorted['tomorrow_rain_mm'] = df_sorted.groupby('gauge_code')['rain_mm'].shift(-1)

    # Calcular soma da chuva nos dias adjacentes
    df_sorted['adjacent_days_mm'] = df_sorted['yesterday_rain_mm'] + df_sorted['tomorrow_rain_mm']

    # Regra para identificar outlier
    condition = (
        (df_sorted['rain_mm'] > threshold_rain_mm) &
        (df_sorted['adjacent_days_mm'] < 0.025 * df_sorted['rain_mm'])
    )

    df_sorted['outlier_status_1'] = np.where(condition, 1, 0)

    return df_sorted

# Aplicar na base df_outlier_filter_1
df_outlier_filter_1 = mark_outlier_rain(df_outlier)
df_outlier_filter_1
# Out:
#           gauge_code   datetime  rain_mm  yesterday_rain_mm  tomorrow_rain_mm  \
# 122174860   00047000 1962-01-01      0.0                NaN               0.0
# 122174861   00047000 1962-01-02      0.0                0.0               0.0
# 122174862   00047000 1962-01-03      0.0                0.0               0.0
# 122174863   00047000 1962-01-04      0.0                0.0               0.0
# 122174864   00047000 1962-01-05      0.0                0.0               0.0
# ...              ...        ...      ...                ...               ...
# 48826156        S716 2021-12-27      0.0                0.0               0.0
# 48826157        S716 2021-12-28      0.0                0.0               0.0
# 48826158        S716 2021-12-29      0.0                0.0               4.4
# 48826159        S716 2021-12-30      4.4                0.0               3.2
# 48826160        S716 2021-12-31      3.2                4.4               NaN
#
#            adjacent_days_mm  outlier_status_1
# 122174860               NaN                 0
# 122174861               0.0                 0
# 122174862               0.0                 0
# 122174863               0.0                 0
# 122174864               0.0                 0
# ...                     ...               ...
# 48826156                0.0                 0
# 48826157                0.0                 0
# 48826158                4.4                 0
# 48826159                3.2                 0
# 48826160                NaN                 0
#
# [112622758 rows x 7 columns]

# %%
# Configurations
neighboring_data_path = './1 - Organized data gauge/BRAZIL'

# %%
df_outlier_filter_1_export = df_outlier_filter_1[df_outlier_filter_1['outlier_status_1'] == 1]
df_outlier_filter_1_export.to_hdf(
        os.path.join(neighboring_data_path, "adjacent_day_analysis_filter_1.h5"),
        key='table_data',
        mode='w',
        format='table',
        complevel=9,
        encoding='utf-8',
        append=False,
        min_itemsize={'gauge_code': 20}  # Adjust based on your max gauge code length
    )
df_outlier_filter_1_export
# Out:
#           gauge_code   datetime  rain_mm  yesterday_rain_mm  tomorrow_rain_mm  \
# 122183545   00047005 2011-01-23    201.8                0.0               0.0
# 122183542   00047005 2011-01-26    201.2                0.0               3.1
# 122415828   00048005 1980-01-14    202.3                0.0               0.0
# 122415748   00048005 1980-04-08    229.3                0.0               0.0
# 122415694   00048005 1981-01-25    238.4                0.0               0.0
# ...              ...        ...      ...                ...               ...
# 3345677     86743950 2021-03-20    566.0                0.0               3.0
# 91180725        A110 2024-01-04    214.6                0.2               2.2
# 31942356        A606 2022-11-27    201.0                0.0               1.0
# 33597804        A667 2023-02-08    288.8                0.0               0.0
# 22262191        A765 2023-02-19    288.8                0.4               3.8
#
#            adjacent_days_mm  outlier_status_1
# 122183545               0.0                 1
# 122183542               3.1                 1
# 122415828               0.0                 1
# 122415748               0.0                 1
# 122415694               0.0                 1
# ...                     ...               ...
# 3345677                 3.0                 1
# 91180725                2.4                 1
# 31942356                1.0                 1
# 33597804                0.0                 1
# 22262191                4.2                 1
#
# [1769 rows x 7 columns]

# %%
df_outlier_filter_1 = df_outlier_filter_1[['gauge_code','datetime',	'rain_mm', 'outlier_status_1']]
df_outlier_filter_1 = df_outlier_filter_1[df_outlier_filter_1['outlier_status_1']==0]
df_outlier_filter_1 = pd.merge(df_outlier_filter_1, df_info[['gauge_code', 'lat', 'long']], on ='gauge_code', how='left')

df_outlier_filter_1
# Out:
#           gauge_code   datetime  rain_mm  outlier_status_1        lat  \
# 0           00047000 1962-01-01      0.0                 0  -0.650000
# 1           00047000 1962-01-02      0.0                 0  -0.650000
# 2           00047000 1962-01-03      0.0                 0  -0.650000
# 3           00047000 1962-01-04      0.0                 0  -0.650000
# 4           00047000 1962-01-05      0.0                 0  -0.650000
# ...              ...        ...      ...               ...        ...
# 112620984       S716 2021-12-27      0.0                 0 -21.305889
# 112620985       S716 2021-12-28      0.0                 0 -21.305889
# 112620986       S716 2021-12-29      0.0                 0 -21.305889
# 112620987       S716 2021-12-30      4.4                 0 -21.305889
# 112620988       S716 2021-12-31      3.2                 0 -21.305889
#
#                 long
# 0         -47.550000
# 1         -47.550000
# 2         -47.550000
# 3         -47.550000
# 4         -47.550000
# ...              ...
# 112620984 -52.820375
# 112620985 -52.820375
# 112620986 -52.820375
# 112620987 -52.820375
# 112620988 -52.820375
#
# [112620989 rows x 6 columns]

# %%
del df_info

# %%
# def idw_interpolation(latitude, longitude, df_temp_without_gauge, kdtree, p=2):
#     row = [latitude, longitude]
#     distances, indices = kdtree.query(row, k=5)
#     weights = 1 / (distances + 1e-6) ** p
#     values = df_temp_without_gauge.iloc[indices]['rain_mm'].values
#     return (np.sum(weights * values) / np.sum(weights))

# # Initialize empty DataFrame for results
# outlier_analysis_results = pd.DataFrame()

# # Configurations
# neighboring_data_path = './1 - Organized data gauge/BRAZIL'
# output_filename = os.path.join(neighboring_data_path, "neighboring_analysis.h5")
# rainfall_threshold = 200.0  # mm

# start_date = '1969-07-01'
# end_date = '2024-12-31'

# df_date = df_outlier_filter_1.loc[(df_outlier_filter_1['datetime'] >= start_date) & (df_outlier_filter_1['datetime'] <= end_date)].sort_values('datetime', ignore_index=True, ascending=True)

# # Get sorted unique dates
# analysis_dates = df_date['datetime'].unique().tolist()
# analysis_dates.sort()

# # Process each date
# for current_date in analysis_dates[:]:
#     # Filter data for current date
#     daily_data = df_outlier_filter_1[df_outlier_filter_1['datetime'] == current_date]
#     gauge_codes = daily_data['gauge_code'].unique()
    
#     date_results = []
    
#     for gauge in gauge_codes:
#         gauge_data = daily_data[daily_data['gauge_code'] == gauge].iloc[0]
#         lat, lon = gauge_data['lat'], gauge_data['long']
#         observed_rain = gauge_data['rain_mm']
        
#         # Initialize result row
#         result_row = {
#             'gauge_code': gauge,
#             'datetime': current_date,
#             'lat': lat,
#             'long': lon,
#             'observed_rain_mm': observed_rain,
#             'interpolated_rain_mm': np.nan
#         }
        
#         # Only interpolate for high rainfall values
#         if observed_rain > rainfall_threshold:
#             neighbor_data = daily_data[daily_data['gauge_code'] != gauge]
            
#             if len(neighbor_data) > 0:
#                 kd_tree = KDTree(neighbor_data[['lat', 'long']].values)
#                 result_row['interpolated_rain_mm'] = idw_interpolation(lat, lon, neighbor_data, kd_tree)
        
#         date_results.append(pd.DataFrame([result_row]))
    
#     # Combine results for current date
#     daily_results = pd.concat(date_results, ignore_index=True)
    
#     # Save to HDF5 with proper configuration
#     # storage_mode = 'w' if current_date == analysis_dates[0] else 'a'
#     # append_mode = False if current_date == analysis_dates[0] else True

#     storage_mode = 'r+'
#     append_mode = True
    
#     daily_results.to_hdf(
#         output_filename,
#         key='table_data',
#         mode=storage_mode,
#         format='table',
#         complevel=9,
#         encoding='utf-8',
#         append=append_mode,
#         min_itemsize={'gauge_code': 20}  # Adjust based on your max gauge code length
#     )
    
#     print(f"Saved results for {current_date} to {output_filename}")
# Out:
# Saved results for 1969-07-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-07-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-08-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-09-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-10-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-11-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1969-12-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-01-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-02-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-03-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-04-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-05-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-06-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-07-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-08-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-09-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 1970-10-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# ...
# Saved results for 2024-07-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-07-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-07-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-07-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-07-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-07-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-07-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-07-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-08-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-09-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-10-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-11-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-01 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-02 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-03 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-04 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-05 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-06 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-07 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-08 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-09 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-10 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-11 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-12 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-13 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-14 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-15 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-16 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-17 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-18 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-19 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-20 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-21 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-22 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-23 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-24 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-25 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-26 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-27 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-28 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-29 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-30 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5
# Saved results for 2024-12-31 00:00:00 to ./1 - Organized data gauge/BRAZIL\neighboring_analysis.h5

# %%
del df_outlier_filter_1

# %%
output_filename = os.path.join(neighboring_data_path, "neighboring_analysis.h5")

df_outlier_2 = pd.read_hdf(output_filename, key='table_data')
df_outlier_2
# Out:
#      gauge_code   datetime        lat       long  observed_rain_mm  \
# 0      00048000 1961-01-01  -0.727800 -48.515800               0.0
# 1      00062000 1961-01-01  -0.971100 -62.928600               0.0
# 2      00067000 1961-01-01  -0.125300 -67.061100               0.0
# 3      00145004 1961-01-01  -1.667800 -45.368300               0.0
# 4      00148001 1961-01-01  -1.450000 -48.500000               0.0
# ...         ...        ...        ...        ...               ...
# 4894       B803 2024-12-31 -24.570833 -52.800278               0.0
# 4895       B804 2024-12-31 -25.368889 -52.391944               0.0
# 4896       B806 2024-12-31 -25.322464 -49.157733               0.0
# 4897       B807 2024-12-31 -30.186111 -51.178056               0.0
# 4898       F501 2024-12-31 -19.980000 -43.958611               0.0
#
#       interpolated_rain_mm
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4894                   NaN
# 4895                   NaN
# 4896                   NaN
# 4897                   NaN
# 4898                   NaN
#
# [112620989 rows x 6 columns]

# %%
df_outlier_filter_2_export = df_outlier_2[df_outlier_2['interpolated_rain_mm'] >= 0.0].reset_index(drop = True)
df_outlier_filter_2_export = df_outlier_filter_2_export[df_outlier_filter_2_export['interpolated_rain_mm'] >= 0.35 * df_outlier_filter_2_export['observed_rain_mm']]
df_outlier_filter_2_export['outlier_status_2'] = 1
df_outlier_filter_2_export
# Out:
#       gauge_code   datetime      lat     long  observed_rain_mm  \
# 7       02346034 1961-01-23 -23.4167 -46.5667            200.30
# 10      02346162 1961-01-26 -23.7000 -46.0667            231.00
# 11      02346223 1961-01-26 -23.7000 -46.0167            272.60
# 12      02345145 1961-01-27 -23.5997 -45.9089            201.40
# 17      02447038 1961-02-16 -24.8000 -47.9667            252.60
# ...          ...        ...      ...      ...               ...
# 3029    82230815 2024-05-27 -25.7122 -48.9706            342.40
# 3030    82234000 2024-05-27 -25.8181 -48.8072            563.00
# 3060    62780700 2024-11-04 -21.8194 -48.8281            218.20
# 3087    65824880 2024-12-09 -25.6406 -51.8603            209.60
# 3095  353760202A 2024-12-23 -24.3600 -47.0180            207.99
#
#       interpolated_rain_mm
# 7               128.216270
# 10              182.781510
# 11              151.228139
# 12               71.139330
# 17              113.109432
# ...                    ...
# 3029            412.382794
# 3030            314.877713
# 3060            120.550931
# 3087             78.153355
# 3095             96.964864
#
# [1207 rows x 6 columns]

# %%
del df_outlier_2

# %%
df_outlier_filter_2_export.to_hdf(
        os.path.join(neighboring_data_path, "neighboring_analysis_filter_2.h5"),
        key='table_data',
        mode='w',
        format='table',
        complevel=9,
        encoding='utf-8',
        append=False,
        min_itemsize={'gauge_code': 20}  # Adjust based on your max gauge code length
    )
df_outlier_filter_2_export
# Out:
#       gauge_code   datetime      lat     long  observed_rain_mm  \
# 7       02346034 1961-01-23 -23.4167 -46.5667            200.30
# 10      02346162 1961-01-26 -23.7000 -46.0667            231.00
# 11      02346223 1961-01-26 -23.7000 -46.0167            272.60
# 12      02345145 1961-01-27 -23.5997 -45.9089            201.40
# 17      02447038 1961-02-16 -24.8000 -47.9667            252.60
# ...          ...        ...      ...      ...               ...
# 3029    82230815 2024-05-27 -25.7122 -48.9706            342.40
# 3030    82234000 2024-05-27 -25.8181 -48.8072            563.00
# 3060    62780700 2024-11-04 -21.8194 -48.8281            218.20
# 3087    65824880 2024-12-09 -25.6406 -51.8603            209.60
# 3095  353760202A 2024-12-23 -24.3600 -47.0180            207.99
#
#       interpolated_rain_mm
# 7               128.216270
# 10              182.781510
# 11              151.228139
# 12               71.139330
# 17              113.109432
# ...                    ...
# 3029            412.382794
# 3030            314.877713
# 3060            120.550931
# 3087             78.153355
# 3095             96.964864
#
# [1207 rows x 6 columns]

# %% [markdown]
# # Data Deletion

# %%
df_filter_1 = pd.read_hdf(os.path.join(neighboring_data_path, "adjacent_day_analysis_filter_1.h5"), key='table_data')
df_filter_1 = df_filter_1[['gauge_code', 'datetime', 'outlier_status_1']]
df_filter_1
# Out:
#           gauge_code   datetime  outlier_status_1
# 122183545   00047005 2011-01-23                 1
# 122183542   00047005 2011-01-26                 1
# 122415828   00048005 1980-01-14                 1
# 122415748   00048005 1980-04-08                 1
# 122415694   00048005 1981-01-25                 1
# ...              ...        ...               ...
# 3345677     86743950 2021-03-20                 1
# 91180725        A110 2024-01-04                 1
# 31942356        A606 2022-11-27                 1
# 33597804        A667 2023-02-08                 1
# 22262191        A765 2023-02-19                 1
#
# [1769 rows x 3 columns]

# %%
df_filter_2 = pd.read_hdf(os.path.join(neighboring_data_path, "neighboring_analysis_filter_2.h5"), key='table_data')
df_filter_2['outlier_status_2'] = 1
df_filter_2 = df_filter_2[['gauge_code', 'datetime', 'outlier_status_2']]
df_filter_2
# Out:
#       gauge_code   datetime  outlier_status_2
# 7       02346034 1961-01-23                 1
# 10      02346162 1961-01-26                 1
# 11      02346223 1961-01-26                 1
# 12      02345145 1961-01-27                 1
# 17      02447038 1961-02-16                 1
# ...          ...        ...               ...
# 3029    82230815 2024-05-27                 1
# 3030    82234000 2024-05-27                 1
# 3060    62780700 2024-11-04                 1
# 3087    65824880 2024-12-09                 1
# 3095  353760202A 2024-12-23                 1
#
# [1207 rows x 3 columns]

# %%
df_data_filtered = pd.merge(df_data, df_filter_1, on = ['gauge_code', 'datetime'], how = 'left').merge(df_filter_2, on = ['gauge_code', 'datetime'], how = 'left')
df_data_filtered = df_data_filtered[(df_data_filtered['outlier_status_1'] != 1) & (df_data_filtered['outlier_status_2'] != 1)]
df_data_filtered
# Out:
#           gauge_code   datetime  rain_mm  outlier_status_1  outlier_status_2
# 0           00047000 1961-01-01      0.0               NaN               NaN
# 1           00047000 1961-01-02      0.0               NaN               NaN
# 2           00047000 1961-01-03      0.0               NaN               NaN
# 3           00047000 1961-01-04      0.0               NaN               NaN
# 4           00047000 1961-01-05      0.0               NaN               NaN
# ...              ...        ...      ...               ...               ...
# 123612837       S717 2021-12-27      0.0               NaN               NaN
# 123612838       S717 2021-12-28      0.0               NaN               NaN
# 123612839       S717 2021-12-29      0.0               NaN               NaN
# 123612840       S717 2021-12-30      0.0               NaN               NaN
# 123612841       S717 2021-12-31      0.0               NaN               NaN
#
# [123609866 rows x 5 columns]

# %%
key = 'table_data_filtered'
chunk_size = 10000000  # Adjust based on available memory

with pd.HDFStore(cleaned_path, mode='r+', complevel=9, complib='blosc') as store:
    for start in range(0, len(df_data_filtered_test), chunk_size):
        end = start + chunk_size
        chunk = df_data_filtered_test.iloc[start:end]
        
        store.append(key, chunk, format='table', data_columns=True, encoding='utf-8', min_itemsize={'gauge_code': 20})

        print(f"Chunk {start // chunk_size + 1} of {len(df_data_filtered_test) // chunk_size + 1} completed.")
# Out:
# Chunk 1 of 13 completed.
# Chunk 2 of 13 completed.
# Chunk 3 of 13 completed.
# Chunk 4 of 13 completed.
# Chunk 5 of 13 completed.
# Chunk 6 of 13 completed.
# Chunk 7 of 13 completed.
# Chunk 8 of 13 completed.
# Chunk 9 of 13 completed.
# Chunk 10 of 13 completed.
# Chunk 11 of 13 completed.
# Chunk 12 of 13 completed.
# Chunk 13 of 13 completed.

# %%
df_data_filtered_test = pd.read_hdf(cleaned_path, key = 'table_data_filtered', encoding = 'utf-8')
df_data_filtered_test
# Out:
#           gauge_code   datetime  rain_mm
# 0           00047000 1961-01-01      0.0
# 1           00047000 1961-01-02      0.0
# 2           00047000 1961-01-03      0.0
# 3           00047000 1961-01-04      0.0
# 4           00047000 1961-01-05      0.0
# ...              ...        ...      ...
# 123612837       S717 2021-12-27      0.0
# 123612838       S717 2021-12-28      0.0
# 123612839       S717 2021-12-29      0.0
# 123612840       S717 2021-12-30      0.0
# 123612841       S717 2021-12-31      0.0
#
# [123609866 rows x 3 columns]

# %%
df_data_filtered_test['gauge_code'].nunique()
# Out:
# 18503
